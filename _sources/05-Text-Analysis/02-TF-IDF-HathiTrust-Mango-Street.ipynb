# %% [markdown]
# # TF-IDF with HathiTrust Data

# %% [markdown]
# In this lesson, we're going to learn about a text analysis method called *term frequency–inverse document frequency*, often abbreviated *tf-idf*.
#
# While calculating the most frequent words in a text can be useful, the most frequent words in a text usually aren't the most interesting words in a text, even if we get rid of stop words ("the, "and," "to," etc.). Tf-idf is a method that builds off word frequency but it more specifically tries to identify the most distinctively frequent or significant words in a document.
#
# In this lesson, we will cover how to:
# - Calculate and normalize tf-idf scores for each chapter in Sandra Cisneros's *The House on Mango Street*
# - Download and process HathiTrust extracted features — that is, word frequencies for books in the HathiTrust Digital Library (including in-copyright books like *The House on Mango Street*)
# - Prepare HathiTrust extracted features for tf-idf analysis

# %% [markdown]
# ## Dataset

# %% [markdown]
# ### *The House on Mango Street* by Sandra Cisneros
#
# ```{epigraph}
#  [T]he pigeon had taken a step and dropped from the ledge. He caught an upwind that took him nearly as high as the tops of the empty K Street houses. He flew farther into Northeast, into the color and sounds of the city's morning. She did nothing, aside from following him, with her eyes, with her heart, as far as she could.
#
# --  Sandra Cisneros, "The Girl Who Raised Pigeons," *The House on Mango Street* (1993)
# ```

# %% [markdown]
# Sandra Cisneros's *The House on Mango Street* (1993) is a collection of 14 short stories set in Washington D.C. The first chapter, "The Girl Who Raised Pigeons," begins with a young girl raising homing pigeons on her roof.
#
# How distinctive is a "pigeon" in the world of *The House on Mango Street*? What does this uniqueness (or lackthereof) tell us about the meaning of pigeons in first chapter "The Girl Who Raised Pigeons" and the collection as a whole? These are just a few of the questions that we're going to try to answer with tf-idf.

# %% [markdown]
# If you already have a collection of plain text (.txt) files that you'd like to analyze, one of the easiest ways to calculate tf-idf scores is to use the Python library scikit-learn. It has a quick and nifty module called [TfidfVectorizer](https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfVectorizer.html), which does all the math for you behind the scenes. We will cover how to use the TfidfVectorizer in the next lesson.
#
# In this lesson, however, we're going to calculate tf-idf scores manually because *The House on Mango Street* is still in-copyright, which means that, for legal reasons, we can't easily share or access plain text files of the book.
#
# Luckily, the [HathiTrust Digital Library](https://www.hathitrust.org/)—which contains digitized books from Google Books as well as many university libraries—has released word frequencies per page for all 17 million books in its catalog. These word frequencies (plus part of speech tags) are otherwise known as "extracted features." There's a lot of text analysis that we can do with extracted features alone, including tf-idf.
#
# So to calculate tf-idf scores for *The House on Mango Street*, we're going to use HathiTrust extracted features. That's why we're not using sci-kit learn's TfidfVectorizer. It works great with plain text files but not so great with extracted features.

# %% [markdown]
# ## Breaking Down the TF-IDF Formula

# %% [markdown]
# But first, let's quickly discuss the tf-idf formula. The idea is pretty simple.

# %% [markdown]
# **tf-idf = term_frequency * inverse_document_frequency**

# %% [markdown]
# **term_frequency** = number of times a given term appears in document

# %% [markdown]
# **inverse_document_frequency** = log(total number of documents / number of documents with term) + 1**\***

# %% [markdown]
# You take the number of times a term occurs in a document (term frequency). Then you take the number of documents in which the same term occurs at least once divided by the total number of documents (document frequency), and you flip that fraction on its head (inverse document frequency). Then you multiply the two numbers together (term_frequency * inverse_document_frequency).
#
# The reason we take the *inverse*, or flipped fraction, of document frequency is to boost the rarer words that occur in relatively few documents. Think about the inverse document frequency for the word "said" vs the word "pigeon." The term "said" appears in 13 (document frequency) of 14 (total documents) *The House on Mango Street* stories (14 / 13 --> a smaller inverse document frequency) while the term "pigeons" only occurs in 2 (document frequency) of the 14 stories (total documents) (14 / 2 --> a bigger inverse document frequency, a bigger tf-idf boost).

# %% [markdown]
# *There are a bunch of slightly different ways that you can calculate inverse document frequency. The version of idf that we're going to use is the [scikit-learn default](https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfTransformer.html#sklearn.feature_extraction.text.TfidfTransformer), which uses "smoothing" aka it adds a "1" to the numerator and denominator:

# %% [markdown]
# **inverse_document_frequency**  = log((1 + total_number_of_documents) / (number_of_documents_with_term +1)) + 1

# %% [markdown]
# ```{margin}
# > If smooth_idf=True (the default), the constant “1” is added to the numerator and denominator of the idf as if an extra document was seen containing every term in the collection exactly once, which prevents zero divisions: idf(t) = log [ (1 + n) / (1 + df(t)) ] + 1.
# > -[scikit-learn documentation](https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfTransformer.html#sklearn.feature_extraction.text.TfidfTransformer)
# ```

# %% [markdown]
# ### Let's test it out

# %% [markdown]
# We need the `log()` function for our calculation, otherwise known as [logarithm](https://en.wikipedia.org/wiki/Logarithm), so we're going to import the `numpy` package.

# %%
import numpy as np

# %% [markdown]
# **"said"**

# %%
total_number_of_documents = 14 ##total number of short stories in *The House on Mango Street*
number_of_documents_with_term = 13 ##number of short stories the contain the word "said"

# %%
term_frequency = 47 ##number of times "said" appears in "The Girl Who Raised Pigeons"
inverse_document_frequency = np.log((1 + total_number_of_documents) / (number_of_documents_with_term +1)) + 1

# %%
term_frequency * inverse_document_frequency
# Out:
# 50.24266495988672

# %% [markdown]
# **"pigeons"**

# %%
total_number_of_documents = 14 ##total number of short stories in *The House on Mango Street*
number_of_documents_with_term = 2 ##number of short stories the contain the word "pigeons"

# %%
term_frequency = 30 ##number of times "pigeons" appears in "The Girl Who Raised Pigeons"
inverse_document_frequency = np.log((1 + total_number_of_documents) / (number_of_documents_with_term +1)) + 1

# %%
term_frequency * inverse_document_frequency
# Out:
# 78.28313737302301

# %% [markdown]
# **tf–idf scores for "The Girl Who Raised Pigeons"**
#
# "said" = 50.48<br>
# "pigeons" = 78.28

# %% [markdown]
# Though the word "said" appears 47 times in "The Girl Who Raised Pigeons" and the word "pigeons" only appears 30 times, "pigeons" has a higher tf–idf score than "said" because it's a rarer word. The word "pigeons" appears in 2 of 14 stories, while "said" appears in 13 of 14 stories, almost all of them.

# %% [markdown]
# ## Get HathiTrust Extracted Features

# %% [markdown]
# Now let's try to calculate tf-idf scores for all the words in all the short stories in *The House on Mango Street*. To do so, we need word counts, or HathiTrust extracted features, for each story in the collection.

# %% [markdown]
# To work with HathiTrust's extracted features, we first need to install and import the [HathiTrust Feature Reader](https://github.com/htrc/htrc-feature-reader).

# %% [markdown]
# Install HathiTrust Feature Reader

# %%
# !pip install htrc-feature-reader

# %% [markdown]
# Import necessary libraries

# %%
from htrc_features import Volume
import pandas as pd

# %%
pd.options.display.max_rows = 800

# %% [markdown]
# Then we need to locate the the HathiTrust volume ID for *The House on Mango Street*. If we search the HathiTrust catalog for this book and then click on "Limited (search only)," it will take us to the following web page: https://babel.hathitrust.org/cgi/pt?id=mdp.39015029970129.
#
# The HathiTrust Volume ID for *The House on Mango Street* is located after `id=` this URL: `mdp.39015029970129`.

# %% [markdown]
# ### Make DataFrame of Word Frequencies From Volume(s)

# %% [markdown]
# #### Single Volume

# %% [markdown]
# To get HathiTrust extracted features for a single volume, we can create a `[Volume` object](https://github.com/htrc/htrc-feature-reader#volume) and use the `.tokenlist()` method.

# %% [markdown]
# For each page in *The House on Mango Street*, this DataFrame displays the page number and section type as well as every word/token that appears on the page, its part-of-speech, and the number of times that word/token occurs on the page. As you can see, there are 51,297 rows in this DataFrame — one for each token that appears on each page.
#
# Let's look at a sample of just 20 words from page 11.

# %%
Volume('uc1.32106012740764').tokenlist()[500:520]
# Out:
#                                 count
# page section token        pos
# 18   body    moment       NN        1
#              much         JJ        1
#              my           PRP$      4
#              n't          RB        1
#              neighborhood NN        1
#              no           DT        1
#                           RB        1
#              not          RB        2
#              odd          JJ        1
#              of           IN        6
#              on           IN        1
#              one          CD        3
#              otherness    NN        1
#              paper        NN        1
#              past         NN        1
#              people       NNS       1
#              peopled      VBN       1
#              place        NN        1
#              placed       VBN       1
#              present      JJ        1

# %% [markdown]
# We can also get metadata for a HathiTrust volume by asking for [certain attributes](https://github.com/htrc/htrc-feature-reader#volume).

# %%
Volume('uc1.32106012740764').year
# Out:
# 1994

# %%
Volume('uc1.32106012740764').page_count
# Out:
# 168

# %%
Volume('uc1.32106012740764').publisher
# Out:
# ['A.A. Knopf', 'Distributed by Random House']

# %% [markdown]
# #### Multiple Volumes

# %% [markdown]
# We might want to get extracted features for multiple volumes at the same time, so we're also going to practice a workflow that will allow us to read in multiple HathiTrust books, even though we're only reading in one book at this moment.

# %% [markdown]
# Insert list of desired HathiTrust volume(s)

# %%
volume_ids = ['uc1.32106012740764']

# %% [markdown]
# Loop through this list of volume IDs and make a DataFrame that includes extracted features, book title, and publication year, then make a list of all DataFrames.

# %%
all_tokens = []

for hathi_id in volume_ids:
    
    #Read in HathiTrust volume
    volume = Volume(hathi_id)
    
    #Make dataframe from token list -- do not include part of speech, sections, or case sensitivity
    token_df = volume.tokenlist(case=False, pos=False, drop_section=True)
    
    #Add book column
    token_df['book'] = volume.title
    
    #Add publication year column
    token_df['year'] = volume.year
    
    all_tokens.append(token_df)

# %% [markdown]
# Concatenate the list of DataFrames

# %%
mango_df = pd.concat(all_tokens)

# %% [markdown]
# Preview the DataFrame

# %%
mango_df
# Out:
#                    count                         book  year
# page lowercase
# 1    -                 3  The house on Mango Street /  1994
#      -|-|-|-           1  The house on Mango Street /  1994
#      _                 1  The house on Mango Street /  1994
#      |                 1  The house on Mango Street /  1994
#      |-                4  The house on Mango Street /  1994
# ...                  ...                          ...   ...
# 166  ſº                1  The house on Mango Street /  1994
# 167  32106             1  The house on Mango Street /  1994
#      o1274             1  The house on Mango Street /  1994
#      o764              1  The house on Mango Street /  1994
#      ||||||||||||      1  The house on Mango Street /  1994
#
# [13780 rows x 3 columns]

# %% [markdown]
# Change from multi-level index to regular index with `reset_index()`

# %%
mango_df_flattened = mango_df.reset_index()

# %%
mango_df_flattened[mango_df_flattened['token'] == 'march']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'token'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-92-4d1c8492f8be> in <module>
# ----> 1 mango_df_flattened[mango_df_flattened['token'] == 'march']
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'token'

# %% [markdown]
# Nice! We now have a DataFrame of word counts per page for *The House on Mango Street*.
#
# But what we need to move forward with tf-idf is a way of splitting this collection into its individual stories. Remember: to use tf-idf, we need a *collection* of texts because we need to compare word frequency for one document with all the other documents in the collection.

# %% [markdown]
# ## Add story titles

# %% [markdown]
# How can we split up *The House on Mango Street* into individual stories?
#
# Sometimes HathiTrust Extracted Features helpfully include "section" information for a book, such as chapter titles. Unfortunately, the extracted features for *The House on Mango Street* do not include chapter or story titles.
#
# They do, however, include page numbers and, if you specify `volume.tokenlist(case=True)`, words with case sensitivity. When I manually combed through the HTRC token list with case sensitivity turned on, I noticed that the title page for each chapter seemed to format the title in all-caps. So I searched for all-caps words from each story title and noted down the corresponding page number. This should give us a marker of where every story begins and ends.

# %% [markdown]
# The function below will add in *The House on Mango Street*'s story titles for the correct page numbers and corresponding words.

# %%
def add_story_titles(page):
    if page >= 0 and page < 29:
        return "Front Matter"
    if page >= 29 and page < 33:
        return "01: The House on Mango Street"
    elif page >= 33 and page < 35:
        return "02: Hairs"
    elif page >= 35 and page < 37:
        return "03: Boys & Girls"
    elif page >= 37 and page < 40:
        return "04: My Name"
    elif page >= 40 and page < 42:
        return "05: Cathy Queen of Cats"
    elif page >= 42 and page < 46:
        return "06: Our Good Day"
    elif page >= 46 and page < 48:
        return "07: Laughter"
    elif page >= 48 and page < 51:
        return "08: Gil's Furniture Bought & Sold"
    elif page >= 51 and page < 54:
        return "09: Meme Ortiz"
    elif page >= 54 and page < 56:
        return "10: Louie, His Cousin, & His Other Cousin"
    elif page >= 56 and page < 59:
        return "11: Marin"
    elif page >= 59 and page < 61:
        return "12: Those Who Don't"
    elif page >= 61 and page < 63:
        return "13: There Was an Old Woman She Had So Many Children She Didn't Know What to Do"
    elif page >= 63 and page <= 64:
        return "14: Alicia Who Sees Mice"
    elif page >= 64 and page <= 67:
        return "15: Darius & the Clouds"
    elif page >= 67 and page <= 72:
        return "16: And Some More"
    elif page >= 72 and page <= 77:
        return "17: The Family of Little Feet"
    elif page >= 77 and page <= 82:
        return "18: A Rice Sandwich"
    elif page >= 82 and page <= 84:
        return "19: Chanclas"
    elif page >= 84 and page <= 90:
        return "20: Hips"
    elif page >= 90 and page <= 94:
        return "21: The First Job"
    elif page >= 94 and page <= 96:
        return "22: Papa Who Wakes Up Tired in the Dark"
    elif page >= 96 and page <= 102:
        return "23: Born Bad"
    elif page >= 102 and page <= 106:
        return "24: Elenita, Cards, Palm, Water"
    elif page >= 106 and page <= 109:
        return "25: Geraldo No Last Name"
    elif page >= 106 and page <= 113:
        return "26: Edna's Ruthie"
    elif page >= 113 and page <= 116:
        return "27: The Earl of Tennesse"
    elif page >= 116 and page <= 119:
        return "28: Sire"
    elif page >= 119 and page <= 120:
        return "29: Four Skinny Trees"
    elif page >= 120 and page <= 124:
        return "30: No Speak English"
    elif page >= 124 and page <= 127:
        return "31: Rafaela Who Drinks Coconut & Papaya Juice on Tuesdays"
    elif page >= 127 and page <= 131:
        return "32: Sally"
    elif page >= 131 and page <= 133:
        return "33: Minerva Writes Poems"
    elif page >= 133 and page <= 136:
        return "34: Bums in the Attic"
    elif page >= 136 and page <= 137:
        return "35: Beautiful & Cruel"
    elif page >= 137 and page <= 139:
        return "36: Smart Cookie"
    elif page >= 139 and page <= 140:
        return "37: What Sally Said"
    elif page >= 140 and page <= 148:
        return "38: The Monkey Garden"
    elif page >= 148 and page <= 150:
        return "39: Red Clowns"
    elif page >= 150 and page <= 151:
        return "40: Linoleum Roses"
    elif page >= 151 and page <= 156:
        return "41: The Three Sisters"
    elif page >= 156 and page <= 158:
        return "42: Alicia & I Talking on Edna's Steps"
    elif page >= 158 and page <= 159:
        return "43: A House of My Own"
    elif page >= 159 and page <= 160:
        return "44: Mango Says Goodbye Sometimes"
    elif page > 160:
        return "Back Matter"

# %% [markdown]
# Below we add a new column of story titles to the DataFrame by `apply()`ing our function to the "page" column and dumping the results to `mango_df_flattened['story']`. You can read more about applying functions in ["Pandas Basics - Part 3"](https://melaniewalsh.github.io/Intro-Cultural-Analytics/Data-Analysis/Pandas-Basics-Part3.html#applying-functions).

# %%
mango_df_flattened['story'] = mango_df_flattened['page'].apply(add_story_titles)

# %% [markdown]
# We're also going to drop the "Front Matter" and "Back Matter" from the DataFrame.

# %%
mango_df_flattened = mango_df_flattened.drop(mango_df_flattened[mango_df_flattened['story'] == 'Front Matter'].index)

# %%
mango_df_flattened = mango_df_flattened.drop(mango_df_flattened[mango_df_flattened['story'] == 'Back Matter'].index)

# %% [markdown]
# ## Sum Word Counts For Each Story

# %% [markdown]
# Page-level information is great. But for tf-idf purposes, we really only care about the frequency of words for every story. Below we group by story and calculate the sum of word frequencies for all the pages in that story.

# %%
mango_df_flattened.groupby(['story', 'lowercase'])[['count']].sum().reset_index()
# Out:
#                                  story lowercase  count
# 0        01: The House on Mango Street        'd      5
# 1        01: The House on Mango Street       're      2
# 2        01: The House on Mango Street        's      4
# 3        01: The House on Mango Street         ,     30
# 4        01: The House on Mango Street        --      3
# ...                                ...       ...    ...
# 8829  44: Mango Says Goodbye Sometimes       who      1
# 8830  44: Mango Says Goodbye Sometimes       why      1
# 8831  44: Mango Says Goodbye Sometimes      will      5
# 8832  44: Mango Says Goodbye Sometimes      with      2
# 8833  44: Mango Says Goodbye Sometimes     write      1
#
# [8834 rows x 3 columns]

# %% [markdown]
# Notice how the "page" column no longer exists in the DataFrame and our rows have slimmed down from more than 40,000 to 18,000.

# %%
word_frequency_df = mango_df_flattened.groupby(['story', 'lowercase'])[['count']].sum().reset_index()

# %% [markdown]
# ## Remove Infrequent Words, Stopwords, & Punctuation

# %% [markdown]
# We will conclude with some final pre-processing steps. We will remove the list of stopwords defined below.

# %% [markdown]
# Make list of stopwords

# %%
STOPS = ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'your', 'yours',
         'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'her', 'hers',
         'herself', 'it', 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves',
         'what', 'which', 'who', 'whom', 'this', 'that', 'these', 'those', 'am', 'is', 'are',
         'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does',
         'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until',
         'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into',
         'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down',
         'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here',
         'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more',
         'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so',
         'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'should', 'now', 've', 'll', 'amp', "!"]

# %% [markdown]
# Remove stopwords

# %%
word_frequency_df = word_frequency_df.drop(word_frequency_df[word_frequency_df['lowercase'].isin(STOPS)].index)

# %% [markdown]
# We will also remove punctuation by using a regular expression `[^A-Za-z\s]`, which matches anything that's not a letter and drops it from the DataFrame.

# %%
word_frequency_df = word_frequency_df.drop(word_frequency_df[word_frequency_df['lowercase'].str.contains('[^A-Za-z\s]', regex=True)].index)

# %%
#Remove words that appear less than 5 times in a book
#word_frequency_df_test = word_frequency_df[word_frequency_df['count'] > 5]

# %%
word_frequency_df
# Out:
#                                  story  lowercase  count
# 12       01: The House on Mango Street     always      3
# 14       01: The House on Mango Street    anybody      1
# 16       01: The House on Mango Street     around      1
# 18       01: The House on Mango Street      asked      1
# 20       01: The House on Mango Street       away      1
# ...                                ...        ...    ...
# 8814  44: Mango Says Goodbye Sometimes  sometimes      1
# 8815  44: Mango Says Goodbye Sometimes     street      2
# 8816  44: Mango Says Goodbye Sometimes     strong      1
# 8821  44: Mango Says Goodbye Sometimes      third      1
# 8833  44: Mango Says Goodbye Sometimes      write      1
#
# [6056 rows x 3 columns]

# %% [markdown]
# ## TF-IDF

# %% [markdown]
# ### Term Frequency

# %% [markdown]
# We already have term frequencies for each document. Let's rename the columns so that they're consistent with the tf-idf vocabulary that we've been using.

# %%
word_frequency_df = word_frequency_df.rename(columns={'lowercase': 'term','count': 'term_frequency'})

# %%
word_frequency_df
# Out:
#                                  story       term  term_frequency
# 12       01: The House on Mango Street     always               3
# 14       01: The House on Mango Street    anybody               1
# 16       01: The House on Mango Street     around               1
# 18       01: The House on Mango Street      asked               1
# 20       01: The House on Mango Street       away               1
# ...                                ...        ...             ...
# 8814  44: Mango Says Goodbye Sometimes  sometimes               1
# 8815  44: Mango Says Goodbye Sometimes     street               2
# 8816  44: Mango Says Goodbye Sometimes     strong               1
# 8821  44: Mango Says Goodbye Sometimes      third               1
# 8833  44: Mango Says Goodbye Sometimes      write               1
#
# [6056 rows x 3 columns]

# %% [markdown]
# ### Document Frequency

# %% [markdown]
# To calculate the number of documents or stories in which each term appears, we're going to create a separate DataFrame and do some Pandas manipulation and calculation.

# %%
document_frequency_df = (word_frequency_df.groupby(['story','term']).size().unstack()).sum().reset_index()

# %% [markdown]
# If you inspect parts of the complex chain of Pandas methods above (which is always a great way to learn!), you will see that we're momentarily reshaping the DataFrame to see if each term appears in each story...

# %%
word_frequency_df.groupby(['story','term']).size().unstack()
# Out:
# term                                                able  abuelito  accent  \
# story
# 01: The House on Mango Street                        NaN       NaN     NaN
# 02: Hairs                                            NaN       NaN     NaN
# 03: Boys & Girls                                     NaN       NaN     NaN
# 04: My Name                                          NaN       NaN     NaN
# 05: Cathy Queen of Cats                              NaN       NaN     NaN
# 06: Our Good Day                                     NaN       NaN     NaN
# 07: Laughter                                         NaN       NaN     NaN
# 08: Gil's Furniture Bought & Sold                    NaN       NaN     NaN
# 09: Meme Ortiz                                       NaN       NaN     NaN
# 10: Louie, His Cousin, & His Other Cousin            NaN       NaN     NaN
# 11: Marin                                            NaN       NaN     NaN
# 12: Those Who Don't                                  NaN       NaN     NaN
# 13: There Was an Old Woman She Had So Many Chil...   NaN       NaN     NaN
# 14: Alicia Who Sees Mice                             NaN       NaN     NaN
# 15: Darius & the Clouds                              NaN       NaN     NaN
# 16: And Some More                                    NaN       NaN     NaN
# 17: The Family of Little Feet                        NaN       NaN     NaN
# 18: A Rice Sandwich                                  NaN       NaN     NaN
# 19: Chanclas                                         NaN       NaN     NaN
# 20: Hips                                             1.0       NaN     NaN
# 21: The First Job                                    NaN       1.0     NaN
# 22: Papa Who Wakes Up Tired in the Dark              NaN       NaN     NaN
# 23: Born Bad                                         NaN       NaN     NaN
# 24: Elenita, Cards, Palm, Water                      NaN       NaN     NaN
# 25: Geraldo No Last Name                             NaN       NaN     NaN
# 26: Edna's Ruthie                                    NaN       NaN     NaN
# 27: The Earl of Tennesse                             NaN       NaN     1.0
# 28: Sire                                             NaN       NaN     NaN
# 29: Four Skinny Trees                                NaN       NaN     NaN
# 30: No Speak English                                 NaN       NaN     NaN
# 31: Rafaela Who Drinks Coconut & Papaya Juice o...   NaN       NaN     NaN
# 32: Sally                                            NaN       NaN     NaN
# 33: Minerva Writes Poems                             NaN       NaN     NaN
# 34: Bums in the Attic                                NaN       NaN     NaN
# 35: Beautiful & Cruel                                NaN       NaN     NaN
# 36: Smart Cookie                                     NaN       NaN     NaN
# 37: What Sally Said                                  NaN       NaN     NaN
# 38: The Monkey Garden                                NaN       NaN     NaN
# 39: Red Clowns                                       NaN       NaN     NaN
# 40: Linoleum Roses                                   NaN       NaN     NaN
# 41: The Three Sisters                                NaN       NaN     NaN
# 42: Alicia & I Talking on Edna's Steps               NaN       NaN     NaN
# 43: A House of My Own                                NaN       NaN     NaN
# 44: Mango Says Goodbye Sometimes                     NaN       NaN     NaN
#
# term                                                accident  account  ache  \
# story
# 01: The House on Mango Street                            NaN      NaN   NaN
# 02: Hairs                                                NaN      NaN   NaN
# 03: Boys & Girls                                         NaN      NaN   NaN
# 04: My Name                                              NaN      NaN   NaN
# 05: Cathy Queen of Cats                                  NaN      NaN   NaN
# 06: Our Good Day                                         NaN      NaN   NaN
# 07: Laughter                                             NaN      NaN   NaN
# 08: Gil's Furniture Bought & Sold                        NaN      NaN   NaN
# 09: Meme Ortiz                                           NaN      NaN   NaN
# 10: Louie, His Cousin, & His Other Cousin                NaN      NaN   NaN
# 11: Marin                                                NaN      NaN   NaN
# 12: Those Who Don't                                      NaN      NaN   NaN
# 13: There Was an Old Woman She Had So Many Chil...       NaN      NaN   NaN
# 14: Alicia Who Sees Mice                                 NaN      NaN   NaN
# 15: Darius & the Clouds                                  NaN      NaN   NaN
# 16: And Some More                                        NaN      NaN   NaN
# 17: The Family of Little Feet                            NaN      NaN   NaN
# 18: A Rice Sandwich                                      NaN      NaN   NaN
# 19: Chanclas                                             NaN      NaN   NaN
# 20: Hips                                                 NaN      NaN   NaN
# 21: The First Job                                        NaN      NaN   NaN
# 22: Papa Who Wakes Up Tired in the Dark                  NaN      NaN   NaN
# 23: Born Bad                                             NaN      NaN   NaN
# 24: Elenita, Cards, Palm, Water                          1.0      1.0   NaN
# 25: Geraldo No Last Name                                 NaN      NaN   NaN
# 26: Edna's Ruthie                                        NaN      NaN   NaN
# 27: The Earl of Tennesse                                 NaN      NaN   NaN
# 28: Sire                                                 NaN      NaN   NaN
# 29: Four Skinny Trees                                    NaN      NaN   NaN
# 30: No Speak English                                     NaN      NaN   NaN
# 31: Rafaela Who Drinks Coconut & Papaya Juice o...       NaN      NaN   NaN
# 32: Sally                                                NaN      NaN   NaN
# 33: Minerva Writes Poems                                 NaN      NaN   NaN
# 34: Bums in the Attic                                    NaN      NaN   NaN
# 35: Beautiful & Cruel                                    NaN      NaN   NaN
# 36: Smart Cookie                                         NaN      NaN   NaN
# 37: What Sally Said                                      NaN      NaN   NaN
# 38: The Monkey Garden                                    NaN      NaN   NaN
# 39: Red Clowns                                           NaN      NaN   NaN
# 40: Linoleum Roses                                       NaN      NaN   NaN
# 41: The Three Sisters                                    NaN      NaN   NaN
# 42: Alicia & I Talking on Edna's Steps                   NaN      NaN   NaN
# 43: A House of My Own                                    NaN      NaN   NaN
# 44: Mango Says Goodbye Sometimes                         NaN      NaN   1.0
#
# term                                                across  add  address   af  \
# story
# 01: The House on Mango Street                          NaN  NaN      NaN  NaN
# 02: Hairs                                              NaN  NaN      NaN  NaN
# 03: Boys & Girls                                       NaN  NaN      NaN  NaN
# 04: My Name                                            NaN  NaN      NaN  NaN
# 05: Cathy Queen of Cats                                1.0  NaN      NaN  NaN
# 06: Our Good Day                                       NaN  NaN      NaN  NaN
# 07: Laughter                                           NaN  NaN      NaN  NaN
# 08: Gil's Furniture Bought & Sold                      1.0  NaN      NaN  NaN
# 09: Meme Ortiz                                         NaN  NaN      NaN  NaN
# 10: Louie, His Cousin, & His Other Cousin              NaN  NaN      NaN  NaN
# 11: Marin                                              NaN  NaN      NaN  NaN
# 12: Those Who Don't                                    NaN  NaN      NaN  NaN
# 13: There Was an Old Woman She Had So Many Chil...     NaN  NaN      NaN  NaN
# 14: Alicia Who Sees Mice                               NaN  NaN      NaN  NaN
# 15: Darius & the Clouds                                NaN  NaN      NaN  NaN
# 16: And Some More                                      NaN  1.0      NaN  NaN
# 17: The Family of Little Feet                          1.0  NaN      NaN  NaN
# 18: A Rice Sandwich                                    1.0  NaN      NaN  NaN
# 19: Chanclas                                           1.0  NaN      NaN  NaN
# 20: Hips                                               1.0  1.0      NaN  NaN
# 21: The First Job                                      NaN  NaN      NaN  NaN
# 22: Papa Who Wakes Up Tired in the Dark                NaN  NaN      NaN  NaN
# 23: Born Bad                                           NaN  NaN      NaN  NaN
# 24: Elenita, Cards, Palm, Water                        1.0  NaN      NaN  NaN
# 25: Geraldo No Last Name                               NaN  NaN      1.0  NaN
# 26: Edna's Ruthie                                      NaN  NaN      NaN  NaN
# 27: The Earl of Tennesse                               1.0  NaN      NaN  NaN
# 28: Sire                                               NaN  NaN      NaN  NaN
# 29: Four Skinny Trees                                  NaN  NaN      NaN  NaN
# 30: No Speak English                                   1.0  NaN      NaN  NaN
# 31: Rafaela Who Drinks Coconut & Papaya Juice o...     NaN  NaN      NaN  NaN
# 32: Sally                                              NaN  NaN      NaN  NaN
# 33: Minerva Writes Poems                               NaN  NaN      NaN  NaN
# 34: Bums in the Attic                                  NaN  NaN      NaN  NaN
# 35: Beautiful & Cruel                                  NaN  NaN      NaN  NaN
# 36: Smart Cookie                                       NaN  NaN      NaN  NaN
# 37: What Sally Said                                    NaN  NaN      NaN  NaN
# 38: The Monkey Garden                                  NaN  NaN      NaN  1.0
# 39: Red Clowns                                         NaN  NaN      NaN  NaN
# 40: Linoleum Roses                                     NaN  NaN      NaN  NaN
# 41: The Three Sisters                                  NaN  NaN      NaN  NaN
# 42: Alicia & I Talking on Edna's Steps                 NaN  NaN      NaN  NaN
# 43: A House of My Own                                  NaN  NaN      NaN  NaN
# 44: Mango Says Goodbye Sometimes                       NaN  NaN      NaN  NaN
#
# term                                                ...  yes  yesterday  yet  \
# story                                               ...
# 01: The House on Mango Street                       ...  1.0        NaN  1.0
# 02: Hairs                                           ...  NaN        NaN  NaN
# 03: Boys & Girls                                    ...  NaN        NaN  NaN
# 04: My Name                                         ...  1.0        NaN  NaN
# 05: Cathy Queen of Cats                             ...  NaN        NaN  NaN
# 06: Our Good Day                                    ...  NaN        NaN  1.0
# 07: Laughter                                        ...  1.0        NaN  NaN
# 08: Gil's Furniture Bought & Sold                   ...  NaN        NaN  NaN
# 09: Meme Ortiz                                      ...  NaN        NaN  NaN
# 10: Louie, His Cousin, & His Other Cousin           ...  NaN        NaN  NaN
# 11: Marin                                           ...  NaN        NaN  1.0
# 12: Those Who Don't                                 ...  NaN        NaN  NaN
# 13: There Was an Old Woman She Had So Many Chil...  ...  NaN        NaN  NaN
# 14: Alicia Who Sees Mice                            ...  NaN        NaN  NaN
# 15: Darius & the Clouds                             ...  NaN        NaN  NaN
# 16: And Some More                                   ...  1.0        NaN  NaN
# 17: The Family of Little Feet                       ...  1.0        NaN  NaN
# 18: A Rice Sandwich                                 ...  1.0        NaN  NaN
# 19: Chanclas                                        ...  1.0        NaN  NaN
# 20: Hips                                            ...  1.0        NaN  NaN
# 21: The First Job                                   ...  NaN        NaN  1.0
# 22: Papa Who Wakes Up Tired in the Dark             ...  NaN        NaN  NaN
# 23: Born Bad                                        ...  1.0        1.0  NaN
# 24: Elenita, Cards, Palm, Water                     ...  1.0        NaN  NaN
# 25: Geraldo No Last Name                            ...  NaN        NaN  NaN
# 26: Edna's Ruthie                                   ...  NaN        NaN  NaN
# 27: The Earl of Tennesse                            ...  NaN        NaN  NaN
# 28: Sire                                            ...  NaN        NaN  NaN
# 29: Four Skinny Trees                               ...  NaN        NaN  NaN
# 30: No Speak English                                ...  NaN        NaN  NaN
# 31: Rafaela Who Drinks Coconut & Papaya Juice o...  ...  NaN        NaN  NaN
# 32: Sally                                           ...  NaN        NaN  NaN
# 33: Minerva Writes Poems                            ...  NaN        NaN  NaN
# 34: Bums in the Attic                               ...  NaN        NaN  NaN
# 35: Beautiful & Cruel                               ...  NaN        NaN  NaN
# 36: Smart Cookie                                    ...  NaN        NaN  NaN
# 37: What Sally Said                                 ...  NaN        NaN  NaN
# 38: The Monkey Garden                               ...  1.0        NaN  NaN
# 39: Red Clowns                                      ...  NaN        NaN  NaN
# 40: Linoleum Roses                                  ...  NaN        NaN  NaN
# 41: The Three Sisters                               ...  1.0        NaN  NaN
# 42: Alicia & I Talking on Edna's Steps              ...  NaN        NaN  NaN
# 43: A House of My Own                               ...  NaN        NaN  NaN
# 44: Mango Says Goodbye Sometimes                    ...  NaN        NaN  NaN
#
# term                                                yolanda  young  youngest  \
# story
# 01: The House on Mango Street                           NaN    NaN       NaN
# 02: Hairs                                               NaN    NaN       1.0
# 03: Boys & Girls                                        NaN    1.0       NaN
# 04: My Name                                             NaN    NaN       NaN
# 05: Cathy Queen of Cats                                 NaN    NaN       NaN
# 06: Our Good Day                                        NaN    NaN       NaN
# 07: Laughter                                            NaN    NaN       NaN
# 08: Gil's Furniture Bought & Sold                       NaN    NaN       NaN
# 09: Meme Ortiz                                          NaN    NaN       NaN
# 10: Louie, His Cousin, & His Other Cousin               NaN    NaN       NaN
# 11: Marin                                               NaN    NaN       NaN
# 12: Those Who Don't                                     NaN    NaN       NaN
# 13: There Was an Old Woman She Had So Many Chil...      NaN    NaN       NaN
# 14: Alicia Who Sees Mice                                NaN    1.0       NaN
# 15: Darius & the Clouds                                 NaN    NaN       NaN
# 16: And Some More                                       1.0    NaN       NaN
# 17: The Family of Little Feet                           NaN    1.0       NaN
# 18: A Rice Sandwich                                     NaN    NaN       NaN
# 19: Chanclas                                            NaN    NaN       NaN
# 20: Hips                                                NaN    NaN       NaN
# 21: The First Job                                       NaN    NaN       NaN
# 22: Papa Who Wakes Up Tired in the Dark                 NaN    NaN       NaN
# 23: Born Bad                                            NaN    NaN       NaN
# 24: Elenita, Cards, Palm, Water                         NaN    1.0       NaN
# 25: Geraldo No Last Name                                NaN    NaN       NaN
# 26: Edna's Ruthie                                       NaN    1.0       NaN
# 27: The Earl of Tennesse                                NaN    NaN       NaN
# 28: Sire                                                NaN    NaN       NaN
# 29: Four Skinny Trees                                   NaN    NaN       NaN
# 30: No Speak English                                    NaN    NaN       NaN
# 31: Rafaela Who Drinks Coconut & Papaya Juice o...      NaN    1.0       NaN
# 32: Sally                                               NaN    1.0       NaN
# 33: Minerva Writes Poems                                NaN    NaN       NaN
# 34: Bums in the Attic                                   NaN    NaN       NaN
# 35: Beautiful & Cruel                                   NaN    NaN       NaN
# 36: Smart Cookie                                        1.0    NaN       NaN
# 37: What Sally Said                                     NaN    NaN       NaN
# 38: The Monkey Garden                                   NaN    NaN       NaN
# 39: Red Clowns                                          NaN    1.0       NaN
# 40: Linoleum Roses                                      NaN    NaN       NaN
# 41: The Three Sisters                                   NaN    NaN       NaN
# 42: Alicia & I Talking on Edna's Steps                  NaN    NaN       NaN
# 43: A House of My Own                                   NaN    NaN       NaN
# 44: Mango Says Goodbye Sometimes                        NaN    NaN       NaN
#
# term                                                yous  yup  zeze  zillion
# story
# 01: The House on Mango Street                        NaN  NaN   NaN      NaN
# 02: Hairs                                            NaN  NaN   NaN      NaN
# 03: Boys & Girls                                     NaN  NaN   NaN      NaN
# 04: My Name                                          NaN  NaN   1.0      NaN
# 05: Cathy Queen of Cats                              NaN  NaN   NaN      NaN
# 06: Our Good Day                                     NaN  NaN   NaN      NaN
# 07: Laughter                                         NaN  NaN   NaN      NaN
# 08: Gil's Furniture Bought & Sold                    NaN  NaN   NaN      NaN
# 09: Meme Ortiz                                       NaN  NaN   NaN      NaN
# 10: Louie, His Cousin, & His Other Cousin            NaN  NaN   NaN      NaN
# 11: Marin                                            NaN  NaN   NaN      NaN
# 12: Those Who Don't                                  NaN  NaN   NaN      NaN
# 13: There Was an Old Woman She Had So Many Chil...   NaN  NaN   NaN      NaN
# 14: Alicia Who Sees Mice                             NaN  NaN   NaN      NaN
# 15: Darius & the Clouds                              NaN  NaN   NaN      1.0
# 16: And Some More                                    1.0  NaN   NaN      NaN
# 17: The Family of Little Feet                        NaN  NaN   NaN      NaN
# 18: A Rice Sandwich                                  NaN  NaN   NaN      NaN
# 19: Chanclas                                         NaN  NaN   NaN      NaN
# 20: Hips                                             NaN  NaN   NaN      NaN
# 21: The First Job                                    NaN  NaN   NaN      NaN
# 22: Papa Who Wakes Up Tired in the Dark              NaN  NaN   NaN      NaN
# 23: Born Bad                                         NaN  NaN   NaN      NaN
# 24: Elenita, Cards, Palm, Water                      NaN  NaN   NaN      NaN
# 25: Geraldo No Last Name                             NaN  NaN   NaN      NaN
# 26: Edna's Ruthie                                    NaN  NaN   NaN      NaN
# 27: The Earl of Tennesse                             NaN  NaN   NaN      NaN
# 28: Sire                                             NaN  NaN   NaN      NaN
# 29: Four Skinny Trees                                NaN  NaN   NaN      NaN
# 30: No Speak English                                 NaN  NaN   NaN      NaN
# 31: Rafaela Who Drinks Coconut & Papaya Juice o...   NaN  NaN   NaN      NaN
# 32: Sally                                            NaN  NaN   NaN      NaN
# 33: Minerva Writes Poems                             NaN  NaN   NaN      NaN
# 34: Bums in the Attic                                NaN  NaN   NaN      NaN
# 35: Beautiful & Cruel                                NaN  NaN   NaN      NaN
# 36: Smart Cookie                                     NaN  1.0   NaN      NaN
# 37: What Sally Said                                  NaN  NaN   NaN      NaN
# 38: The Monkey Garden                                NaN  NaN   NaN      NaN
# 39: Red Clowns                                       NaN  NaN   NaN      NaN
# 40: Linoleum Roses                                   NaN  NaN   NaN      NaN
# 41: The Three Sisters                                NaN  NaN   NaN      NaN
# 42: Alicia & I Talking on Edna's Steps               NaN  NaN   NaN      NaN
# 43: A House of My Own                                NaN  NaN   NaN      NaN
# 44: Mango Says Goodbye Sometimes                     NaN  NaN   NaN      NaN
#
# [44 rows x 2259 columns]

# %% [markdown]
# Then we're adding up how many stories each term appears in (`.sum()`) and resetting the index (`.reset_index()`) to make a DataFrame.

# %% [markdown]
# Finally, we will rename the column in this DataFrame and merge it into our word frequency DataFrame.

# %%
document_frequency_df = document_frequency_df.rename(columns={0:'document_frequency'})

# %%
word_frequency_df = word_frequency_df.merge(document_frequency_df)

# %% [markdown]
# Now we have term frequency and document frequency.

# %%
word_frequency_df
# Out:
#                                  story    term  term_frequency  \
# 0        01: The House on Mango Street  always               3
# 1                          04: My Name  always               1
# 2                            11: Marin  always               1
# 3        17: The Family of Little Feet  always               1
# 4                  18: A Rice Sandwich  always               2
# ...                                ...     ...             ...
# 6051  44: Mango Says Goodbye Sometimes    ache               1
# 6052  44: Mango Says Goodbye Sometimes   ghost               1
# 6053  44: Mango Says Goodbye Sometimes   march               1
# 6054  44: Mango Says Goodbye Sometimes    pack               1
# 6055  44: Mango Says Goodbye Sometimes    sets               1
#
#       document_frequency
# 0                   15.0
# 1                   15.0
# 2                   15.0
# 3                   15.0
# 4                   15.0
# ...                  ...
# 6051                 1.0
# 6052                 1.0
# 6053                 1.0
# 6054                 1.0
# 6055                 1.0
#
# [6056 rows x 4 columns]

# %% [markdown]
# As you can see in the DataFrame above, the term "abandoned" appears 2 times in the story "The Girl Who Raised Pigeons" (term frequency), and it appears in 3 different stories in the collection overall (document frequency).

# %% [markdown]
# ### Total Number of Documents

# %% [markdown]
# To calculate the total number of documents are in the collection, we count how many unique values are in the "story" column (we know the answer should be 14 short stories).

# %%
total_number_of_documents = mango_df_flattened['story'].nunique()

# %%
total_number_of_documents
# Out:
# 44

# %% [markdown]
# ### Inverse Document Frequency

# %% [markdown]
# As we previously established, there are a lot of slightly different versions of the tf-idf formula, but we're going to use the default version from the [scikit-learn library](https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfTransformer.html#sklearn.feature_extraction.text.TfidfTransformer) that adds "smoothing" to inverse document frequency.

# %% [markdown]
# ```
# inverse_document_frequency = log [ (1 + total number of docs) / (1 + document frequency) ] + 1
# ```

# %%
import numpy as np

# %%
word_frequency_df['idf'] = np.log((1 + total_number_of_documents) / (1 + word_frequency_df['document_frequency'])) + 1

# %% [markdown]
# ### TF- IDF

# %% [markdown]
# Finally, we will calculate tf-idf by multiplying term frequency and inverse document frequency together.

# %%
word_frequency_df['tfidf'] = word_frequency_df['term_frequency'] * word_frequency_df['idf']

# %% [markdown]
# Then we will normalize these values with the scikit-learn library.

# %%
from sklearn import preprocessing

# %%
word_frequency_df['tfidf_normalized'] = preprocessing.normalize(word_frequency_df[['tfidf']], axis=0, norm='l2')

# %% [markdown]
# We did it! Now let's inspect the top 15 words with the highest tfidf scores for each story in the collection

# %%
word_frequency_df[word_frequency_df['story'] == '01 The House on Mango Street'

# %%
sorted_df = word_frequency_df.sort_values(by=['story','tfidf_normalized'], ascending=[True,False]).groupby(['story']).head(15)

# %%
sorted_df[sorted_df['story'] == '01: The House on Mango Street']
# Out:
#                               story    term  term_frequency  \
# 447   01: The House on Mango Street   house              17
# 726   01: The House on Mango Street   mango               7
# 1352  01: The House on Mango Street   would               9
# 878   01: The House on Mango Street    papa               6
# 1098  01: The House on Mango Street  street               7
# 1076  01: The House on Mango Street   small               4
# 1370  01: The House on Mango Street    yard               4
# 1081  01: The House on Mango Street  stairs               5
# 674   01: The House on Mango Street  loomis               3
# 1166  01: The House on Mango Street   third               3
# 712   01: The House on Mango Street    mama               5
# 605   01: The House on Mango Street    live               4
# 327   01: The House on Mango Street   floor               3
# 614   01: The House on Mango Street   lived               3
# 335   01: The House on Mango Street   front               4
#
#       document_frequency       idf      tfidf  tfidf_normalized
# 447                 21.0  1.715620  29.165541          0.073140
# 726                 10.0  2.408767  16.861371          0.042284
# 1352                18.0  1.862224  16.760012          0.042030
# 878                  8.0  2.609438  15.656627          0.039263
# 1098                14.0  2.098612  14.690286          0.036839
# 1076                 3.0  3.420368  13.681473          0.034310
# 1370                 3.0  3.420368  13.681473          0.034310
# 1081                 7.0  2.727221  13.636105          0.034196
# 674                  2.0  3.708050  11.124151          0.027896
# 1166                 2.0  3.708050  11.124151          0.027896
# 712                 14.0  2.098612  10.493061          0.026314
# 605                  9.0  2.504077  10.016310          0.025118
# 327                  4.0  3.197225   9.591674          0.024053
# 614                  5.0  3.014903   9.044709          0.022682
# 335                 12.0  2.241713   8.966853          0.022487

# %%
sorted_df[sorted_df['story'] == '02: Hairs']
# Out:
#           story       term  term_frequency  document_frequency       idf  \
# 1434  02: Hairs       hair               9                 7.0  2.727221
# 1578  02: Hairs    snoring               2                 1.0  4.113515
# 1404  02: Hairs      bread               2                 2.0  3.708050
# 1603  02: Hairs       warm               2                 2.0  3.708050
# 443   02: Hairs    holding               2                 5.0  3.014903
# 1534  02: Hairs       rain               2                 6.0  2.860752
# 1569  02: Hairs      smell               2                 7.0  2.727221
# 540   02: Hairs       like               5                41.0  1.068993
# 879   02: Hairs       papa               2                 8.0  2.609438
# 1401  02: Hairs       bake               1                 1.0  4.113515
# 1402  02: Hairs      bands               1                 1.0  4.113515
# 1403  02: Hairs  barrettes               1                 1.0  4.113515
# 1414  02: Hairs      curly               1                 1.0  4.113515
# 1441  02: Hairs      hairs               1                 1.0  4.113515
# 1450  02: Hairs       lazy               1                 1.0  4.113515
#
#           tfidf  tfidf_normalized
# 1434  24.544989          0.061552
# 1578   8.227031          0.020631
# 1404   7.416100          0.018598
# 1603   7.416100          0.018598
# 443    6.029806          0.015121
# 1534   5.721505          0.014348
# 1569   5.454442          0.013678
# 540    5.344964          0.013404
# 879    5.218876          0.013088
# 1401   4.113515          0.010316
# 1402   4.113515          0.010316
# 1403   4.113515          0.010316
# 1414   4.113515          0.010316
# 1441   4.113515          0.010316
# 1450   4.113515          0.010316

# %%
sorted_df[sorted_df['story'] == '07: Laughter']
# Out:
#              story      term  term_frequency  document_frequency       idf  \
# 3014  07: Laughter    mexico               3                 2.0  3.708050
# 2740  07: Laughter      lucy               3                 9.0  2.504077
# 545   07: Laughter      like               7                41.0  1.068993
# 469   07: Laughter    houses               2                 2.0  3.708050
# 2994  07: Laughter  laughter               2                 2.0  3.708050
# 2764  07: Laughter    rachel               3                10.0  2.408767
# 2989  07: Laughter   exactly               2                 3.0  3.420368
# 1719  07: Laughter     right               3                12.0  2.241713
# 764   07: Laughter     nenny               3                16.0  1.973449
# 1425  07: Laughter    family               2                 7.0  2.727221
# 451   07: Laughter     house               3                21.0  1.715620
# 654   07: Laughter    looked               2                10.0  2.408767
# 626   07: Laughter      look               3                27.0  1.474458
# 2967  07: Laughter  breaking               1                 1.0  4.113515
# 2992  07: Laughter    giggle               1                 1.0  4.113515
#
#           tfidf  tfidf_normalized
# 3014  11.124151          0.027896
# 2740   7.512232          0.018839
# 545    7.482950          0.018765
# 469    7.416100          0.018598
# 2994   7.416100          0.018598
# 2764   7.226302          0.018122
# 2989   6.840736          0.017155
# 1719   6.725139          0.016865
# 764    5.920347          0.014847
# 1425   5.454442          0.013678
# 451    5.146860          0.012907
# 654    4.817534          0.012081
# 626    4.423374          0.011093
# 2967   4.113515          0.010316
# 2992   4.113515          0.010316

# %%
sorted_df[sorted_df['story'] == '07: Laughter']
# Out:
#              story      term  term_frequency  document_frequency       idf  \
# 3014  07: Laughter    mexico               3                 2.0  3.708050
# 2740  07: Laughter      lucy               3                 9.0  2.504077
# 545   07: Laughter      like               7                41.0  1.068993
# 469   07: Laughter    houses               2                 2.0  3.708050
# 2994  07: Laughter  laughter               2                 2.0  3.708050
# 2764  07: Laughter    rachel               3                10.0  2.408767
# 2989  07: Laughter   exactly               2                 3.0  3.420368
# 1719  07: Laughter     right               3                12.0  2.241713
# 764   07: Laughter     nenny               3                16.0  1.973449
# 1425  07: Laughter    family               2                 7.0  2.727221
# 451   07: Laughter     house               3                21.0  1.715620
# 654   07: Laughter    looked               2                10.0  2.408767
# 626   07: Laughter      look               3                27.0  1.474458
# 2967  07: Laughter  breaking               1                 1.0  4.113515
# 2992  07: Laughter    giggle               1                 1.0  4.113515
#
#           tfidf  tfidf_normalized
# 3014  11.124151          0.027896
# 2740   7.512232          0.018839
# 545    7.482950          0.018765
# 469    7.416100          0.018598
# 2994   7.416100          0.018598
# 2764   7.226302          0.018122
# 2989   6.840736          0.017155
# 1719   6.725139          0.016865
# 764    5.920347          0.014847
# 1425   5.454442          0.013678
# 451    5.146860          0.012907
# 654    4.817534          0.012081
# 626    4.423374          0.011093
# 2967   4.113515          0.010316
# 2992   4.113515          0.010316

# %%
sorted_df[sorted_df['story'] == '18: A Rice Sandwich']
# Out:
#                     story      term  term_frequency  document_frequency  \
# 2011  18: A Rice Sandwich       new               6                 6.0
# 717   18: A Rice Sandwich      mama               7                14.0
# 4618  18: A Rice Sandwich      less               3                 1.0
# 4703  18: A Rice Sandwich  superior               3                 1.0
# 4563  18: A Rice Sandwich     dress               4                 5.0
# 1691  18: A Rice Sandwich      kids               5                10.0
# 1043  18: A Rice Sandwich    school               5                12.0
# 3710  18: A Rice Sandwich    letter               3                 2.0
# 4650  18: A Rice Sandwich     nacho               3                 2.0
# 4717  18: A Rice Sandwich     uncle               3                 2.0
# 272   18: A Rice Sandwich      even               5                13.0
# 1178  18: A Rice Sandwich     three               4                10.0
# 4304  18: A Rice Sandwich       eat               3                 4.0
# 4350  18: A Rice Sandwich     lunch               3                 4.0
# 379   18: A Rice Sandwich        go               6                26.0
#
#            idf      tfidf  tfidf_normalized
# 2011  2.860752  17.164514          0.043044
# 717   2.098612  14.690286          0.036839
# 4618  4.113515  12.340546          0.030947
# 4703  4.113515  12.340546          0.030947
# 4563  3.014903  12.059612          0.030242
# 1691  2.408767  12.043836          0.030203
# 1043  2.241713  11.208566          0.028108
# 3710  3.708050  11.124151          0.027896
# 4650  3.708050  11.124151          0.027896
# 4717  3.708050  11.124151          0.027896
# 272   2.167605  10.838026          0.027179
# 1178  2.408767   9.635069          0.024162
# 4304  3.197225   9.591674          0.024053
# 4350  3.197225   9.591674          0.024053
# 379   1.510826   9.064954          0.022733

# %%
word_frequency_df.sort_values(by=['story','tfidf_normalized'], ascending=[True,False]).groupby(['story']).head(15)
# Out:
#                                                   story            term  \
# 447                       01: The House on Mango Street           house
# 726                       01: The House on Mango Street           mango
# 1352                      01: The House on Mango Street           would
# 878                       01: The House on Mango Street            papa
# 1098                      01: The House on Mango Street          street
# 1076                      01: The House on Mango Street           small
# 1370                      01: The House on Mango Street            yard
# 1081                      01: The House on Mango Street          stairs
# 674                       01: The House on Mango Street          loomis
# 1166                      01: The House on Mango Street           third
# 712                       01: The House on Mango Street            mama
# 605                       01: The House on Mango Street            live
# 327                       01: The House on Mango Street           floor
# 614                       01: The House on Mango Street           lived
# 335                       01: The House on Mango Street           front
# 1434                                          02: Hairs            hair
# 1578                                          02: Hairs         snoring
# 1404                                          02: Hairs           bread
# 1603                                          02: Hairs            warm
# 443                                           02: Hairs         holding
# 1534                                          02: Hairs            rain
# 1569                                          02: Hairs           smell
# 540                                           02: Hairs            like
# 879                                           02: Hairs            papa
# 1401                                          02: Hairs            bake
# 1402                                          02: Hairs           bands
# 1403                                          02: Hairs       barrettes
# 1414                                          02: Hairs           curly
# 1441                                          02: Hairs           hairs
# 1450                                          02: Hairs            lazy
# 1680                                   03: Boys & Girls           girls
# 1618                                   03: Boys & Girls            boys
# 1670                                   03: Boys & Girls          friend
# 1608                                   03: Boys & Girls         balloon
# 761                                    03: Boys & Girls           nenny
# 1611                                   03: Boys & Girls            best
# 1687                                   03: Boys & Girls           jokes
# 1717                                   03: Boys & Girls  responsibility
# 1752                                   03: Boys & Girls         secrets
# 1759                                   03: Boys & Girls        separate
# 1812                                   03: Boys & Girls        universe
# 1817                                   03: Boys & Girls          worlds
# 1606                                   03: Boys & Girls          anchor
# 1627                                   03: Boys & Girls        brothers
# 1661                                   03: Boys & Girls         example
# 1999                                        04: My Name            name
# 1975                                        04: My Name           means
# 1845                                        04: My Name         chinese
# 1924                                        04: My Name           horse
# 542                                         04: My Name            like
# 1957                                        04: My Name       magdalena
# 2189                                        04: My Name            zeze
# 1860                                        04: My Name       esperanza
# 1840                                        04: My Name            born
# 2050                                        04: My Name         sadness
# 2181                                        04: My Name           women
# 2160                                        04: My Name            wild
# 684                                         04: My Name            made
# 2087                                        04: My Name         spanish
# 2175                                        04: My Name           woman
# 2248                            05: Cathy Queen of Cats            cats
# 424                             05: Cathy Queen of Cats           great
# 2404                            05: Cathy Queen of Cats           queen
# 2245                            05: Cathy Queen of Cats           cathy
# 2337                            05: Cathy Queen of Cats         farther
# 2349                            05: Cathy Queen of Cats          france
# 2361                            05: Cathy Queen of Cats           grand
# 2430                            05: Cathy Queen of Cats            sold
# 2237                            05: Cathy Queen of Cats        building
# 738                             05: Cathy Queen of Cats            move
# 2396                            05: Cathy Queen of Cats            okay
# 776                             05: Cathy Queen of Cats            next
# 2283                            05: Cathy Queen of Cats            ever
# 1871                            05: Cathy Queen of Cats          father
# 2262                            05: Cathy Queen of Cats          cousin
# 2581                                   06: Our Good Day         dollars
# 2625                                   06: Our Good Day            five
# 2527                                   06: Our Good Day            bike
# 2773                                   06: Our Good Day            ride
# 2763                                   06: Our Good Day          rachel
# 2739                                   06: Our Good Day            lucy
# 2246                                   06: Our Good Day           cathy
# 2898                                   06: Our Good Day           texas
# 352                                    06: Our Good Day             get
# 1008                                   06: Our Good Day            says
# 2010                                   06: Our Good Day             new
# 2724                                   06: Our Good Day            load
# 2917                                   06: Our Good Day           today
# 2040                                   06: Our Good Day           quite
# 2525                                   06: Our Good Day         bicycle
# 3014                                       07: Laughter          mexico
# 2740                                       07: Laughter            lucy
# 545                                        07: Laughter            like
# 469                                        07: Laughter          houses
# 2994                                       07: Laughter        laughter
# 2764                                       07: Laughter          rachel
# 2989                                       07: Laughter         exactly
# 1719                                       07: Laughter           right
# 764                                        07: Laughter           nenny
# 1425                                       07: Laughter          family
# 451                                        07: Laughter           house
# 654                                        07: Laughter          looked
# 626                                        07: Laughter            look
# 2967                                       07: Laughter        breaking
# 2992                                       07: Laughter          giggle
# 3069                  08: Gil's Furniture Bought & Sold             box
# 3185                  08: Gil's Furniture Bought & Sold             man
# 810                   08: Gil's Furniture Bought & Sold             old
# 3067                  08: Gil's Furniture Bought & Sold          bought
# 765                   08: Gil's Furniture Bought & Sold           nenny
# 2434                  08: Gil's Furniture Bought & Sold           store
# 3037                  08: Gil's Furniture Bought & Sold          asking
# 3241                  08: Gil's Furniture Bought & Sold            rows
# 1802                  08: Gil's Furniture Bought & Sold            turn
# 2431                  08: Gil's Furniture Bought & Sold            sold
# 3127                  08: Gil's Furniture Bought & Sold         fingers
# 3135                  08: Gil's Furniture Bought & Sold       furniture
# 1137                  08: Gil's Furniture Bought & Sold          things
# 2798                  08: Gil's Furniture Bought & Sold             see
# 3113                  08: Gil's Furniture Bought & Sold      everything
# 3399                                     09: Meme Ortiz            meme
# 1426                                     09: Meme Ortiz          family
# 3389                                     09: Meme Ortiz           louie
# 3330                                     09: Meme Ortiz             dog
# 3451                                     09: Meme Ortiz            tree
# 2247                                     09: Meme Ortiz           cathy
# 3404                                     09: Meme Ortiz           names
# 2001                                     09: Meme Ortiz            name
# 743                                      09: Meme Ortiz           moved
# 3416                                     09: Meme Ortiz           ortiz
# 3436                                     09: Meme Ortiz      scrambling
# 3453                                     09: Meme Ortiz          tucked
# 2263                                     09: Meme Ortiz          cousin
# 3304                                     09: Meme Ortiz           calls
# 3417                                     09: Meme Ortiz          puerto
# 3390          10: Louie, His Cousin, & His Other Cousin           louie
# 165           10: Louie, His Cousin, & His Other Cousin             car
# 3457          10: Louie, His Cousin, & His Other Cousin           alley
# 2264          10: Louie, His Cousin, & His Other Cousin          cousin
# 3632          10: Louie, His Cousin, & His Other Cousin          yellow
# 3485          10: Louie, His Cousin, & His Other Cousin        cadillac
# 3487          10: Louie, His Cousin, & His Other Cousin             cop
# 3495          10: Louie, His Cousin, & His Other Cousin           drove
# 679           10: Louie, His Cousin, & His Other Cousin             lot
# 2534          10: Louie, His Cousin, & His Other Cousin           block
# 3573          10: Louie, His Cousin, & His Other Cousin           seats
# 1772          10: Louie, His Cousin, & His Other Cousin         sisters
# 36            10: Louie, His Cousin, & His Other Cousin           asked
# 1193          10: Louie, His Cousin, & His Other Cousin            time
# 1315          10: Louie, His Cousin, & His Other Cousin           white
# 3395                                          11: Marin           marin
# 1264                                          11: Marin              us
# 1763                                          11: Marin           since
# 1619                                          11: Marin            boys
# 3559                                          11: Marin           radio
# 355                                           11: Marin             get
# 2444                                          11: Marin          taking
# 3646                                          11: Marin            aunt
# 3698                                          11: Marin             job
# 1138                                          11: Marin          things
# 2799                                          11: Marin             see
# 3276                                          11: Marin            work
# 3771                                          11: Marin         someone
# 1375                                          11: Marin            year
# 1613                                          11: Marin            best
# 2392                                12: Those Who Don't    neighborhood
# 1888                                12: Those Who Don't            goes
# 3807                                12: Those Who Don't             boy
# 2600                                12: Those Who Don't             fat
# 3806                                12: Those Who Don't          attack
# 3816                                12: Those Who Don't            brim
# 3823                                12: Those Who Don't           drive
# 3828                                12: Those Who Don't           grown
# 3829                                12: Those Who Don't             guy
# 3834                                12: Those Who Don't          knives
# 3844                                12: Those Who Don't           straw
# 1152                                12: Those Who Don't           think
# 3684                                12: Those Who Don't           davey
# 3824                                12: Those Who Don't            dumb
# 3826                                12: Those Who Don't           eddie
# 1689  13: There Was an Old Woman She Had So Many Chi...            kids
# 270   13: There Was an Old Woman She Had So Many Chi...            even
# 1333  13: There Was an Old Woman She Had So Many Chi...         without
# 1960  13: There Was an Old Woman She Had So Many Chi...            many
# 1814  13: There Was an Old Woman She Had So Many Chi...          vargas
# 3942  13: There Was an Old Woman She Had So Many Chi...           tired
# 2225  13: There Was an Old Woman She Had So Many Chi...           benny
# 1634  13: There Was an Old Woman She Had So Many Chi...            come
# 215   13: There Was an Old Woman She Had So Many Chi...             day
# 507   13: There Was an Old Woman She Had So Many Chi...            know
# 3857  13: There Was an Old Woman She Had So Many Chi...         babying
# 3860  13: There Was an Old Woman She Had So Many Chi...         bologna
# 3861  13: There Was an Old Woman She Had So Many Chi...        bottling
# 3862  13: There Was an Old Woman She Had So Many Chi...          bounce
# 3867  13: There Was an Old Woman She Had So Many Chi...            buck
# 2200                           14: Alicia Who Sees Mice          alicia
# 3998                           14: Alicia Who Sees Mice            mice
# 4008                           14: Alicia Who Sees Mice             pin
# 4009                           14: Alicia Who Sees Mice            rise
# 4010                           14: Alicia Who Sees Mice         rolling
# 4019                           14: Alicia Who Sees Mice         studies
# 2054                           14: Alicia Who Sees Mice            sees
# 3982                           14: Alicia Who Sees Mice           early
# 1873                           14: Alicia Who Sees Mice          father
# 3960                           14: Alicia Who Sees Mice          behind
# 715                            14: Alicia Who Sees Mice            mama
# 3959                           14: Alicia Who Sees Mice         appears
# 3972                           14: Alicia Who Sees Mice           catch
# 3985                           14: Alicia Who Sees Mice           exist
# 3986                           14: Alicia Who Sees Mice         factory
# 4048                            15: Darius & the Clouds          darius
# 3928                            15: Darius & the Clouds             sky
# 4054                            15: Darius & the Clouds             god
# 1416                            15: Darius & the Clouds       different
# 3158                            15: Darius & the Clouds           kinds
# 4058                            15: Darius & the Clouds            kind
# 4080                            15: Darius & the Clouds            snow
# 4086                            15: Darius & the Clouds          thirty
# 978                             15: Darius & the Clouds            said
# 3091                            15: Darius & the Clouds           dirty
# 4044                            15: Darius & the Clouds          clouds
# 2801                            15: Darius & the Clouds             see
# 4035                            15: Darius & the Clouds           clean
# 2918                            15: Darius & the Clouds           today
# 1014                            15: Darius & the Clouds            says
# 4118                                  16: And Some More         cumulus
# 4045                                  16: And Some More          clouds
# 3406                                  16: And Some More           names
# 3048                                  16: And Some More          better
# 4129                                  16: And Some More            face
# 553                                   16: And Some More            like
# 4250                                  16: And Some More            ugly
# 3121                                  16: And Some More            feet
# 2766                                  16: And Some More          rachel
# 767                                   16: And Some More           nenny
# 666                                   16: And Some More           looks
# 716                                   16: And Some More            mama
# 1862                                  16: And Some More       esperanza
# 2742                                  16: And Some More            lucy
# 2602                                  16: And Some More             fat
# 2822                      17: The Family of Little Feet           shoes
# 4283                      17: The Family of Little Feet             bum
# 4343                      17: The Family of Little Feet           lemon
# 2767                      17: The Family of Little Feet          rachel
# 2743                      17: The Family of Little Feet            lucy
# 4367                      17: The Family of Little Feet            pale
# 554                       17: The Family of Little Feet            like
# 3096                      17: The Family of Little Feet          dollar
# 3473                      17: The Family of Little Feet            blue
# 4313                      17: The Family of Little Feet            high
# 1384                      17: The Family of Little Feet             yes
# 3189                      17: The Family of Little Feet             man
# 3220                      17: The Family of Little Feet            pair
# 4285                      17: The Family of Little Feet         canteen
# 1016                      17: The Family of Little Feet            says
# 2011                                18: A Rice Sandwich             new
# 717                                 18: A Rice Sandwich            mama
# 4618                                18: A Rice Sandwich            less
# 4703                                18: A Rice Sandwich        superior
# 4563                                18: A Rice Sandwich           dress
# 1691                                18: A Rice Sandwich            kids
# 1043                                18: A Rice Sandwich          school
# 3710                                18: A Rice Sandwich          letter
# 4650                                18: A Rice Sandwich           nacho
# 4717                                18: A Rice Sandwich           uncle
# 272                                 18: A Rice Sandwich            even
# 1178                                18: A Rice Sandwich           three
# 4304                                18: A Rice Sandwich             eat
# 4350                                18: A Rice Sandwich           lunch
# 379                                 18: A Rice Sandwich              go
# 4718                                       19: Chanclas           uncle
# 4548                                       19: Chanclas           dance
# 4777                                       19: Chanclas         watches
# 1463                                       19: Chanclas          mother
# 556                                        19: Chanclas            like
# 4760                                       19: Chanclas           ready
# 1386                                       19: Chanclas             yes
# 2012                                       19: Chanclas             new
# 4636                                       19: Chanclas           maybe
# 3124                                       19: Chanclas            feet
# 1621                                       19: Chanclas            boys
# 3810                                       19: Chanclas             boy
# 2619                                       19: Chanclas           first
# 4736                                       19: Chanclas             bow
# 4737                                       19: Chanclas           buick
# 4637                                           20: Hips           maybe
# 4749                                           20: Hips            hips
# 3607                                           20: Hips              ta
# 1387                                           20: Hips             yes
# 2744                                           20: Hips            lucy
# 4908                                           20: Hips         turning
# 2768                                           20: Hips          rachel
# 4789                                           20: Hips          begins
# 1738                                           20: Hips             say
# 362                                            20: Hips             get
# 769                                            20: Hips           nenny
# 557                                            20: Hips            like
# 412                                            20: Hips             got
# 4404                                           20: Hips            rope
# 1805                                           20: Hips            turn
# 4988                                  21: The First Job            lala
# 982                                   21: The First Job            said
# 3647                                  21: The First Job            aunt
# 4691                                  21: The First Job         started
# 5005                                  21: The First Job           photo
# 782                                   21: The First Job            next
# 3310                                  21: The First Job            came
# 881                                   21: The First Job            papa
# 1197                                  21: The First Job            time
# 4972                                  21: The First Job       finishers
# 5003                                  21: The First Job             pan
# 5004                                  21: The First Job           peter
# 5013                                  21: The First Job           shift
# 3410                                  21: The First Job           older
# 381                                   21: The First Job              go
# 4595            22: Papa Who Wakes Up Tired in the Dark            hold
# 5058            22: Papa Who Wakes Up Tired in the Dark          likely
# 5059            22: Papa Who Wakes Up Tired in the Dark            lupe
# 882             22: Papa Who Wakes Up Tired in the Dark            papa
# 1842            22: Papa Who Wakes Up Tired in the Dark            born
# 3648            22: Papa Who Wakes Up Tired in the Dark            aunt
# 1600            22: Papa Who Wakes Up Tired in the Dark           thick
# 2922            22: Papa Who Wakes Up Tired in the Dark           today
# 3080            22: Papa Who Wakes Up Tired in the Dark            dark
# 5041            22: Papa Who Wakes Up Tired in the Dark           combs
# 5048            22: Papa Who Wakes Up Tired in the Dark         deserve
# 5054            22: Papa Who Wakes Up Tired in the Dark       guadalupe
# 5055            22: Papa Who Wakes Up Tired in the Dark            hell
# 5060            22: Papa Who Wakes Up Tired in the Dark     photographs
# 5061            22: Papa Who Wakes Up Tired in the Dark            pray
# 4638                                       23: Born Bad           maybe
# 222                                        23: Born Bad             day
# 3649                                       23: Born Bad            aunt
# 5223                                       23: Born Bad          totchy
# 4032                                       23: Born Bad            book
# 5131                                       23: Born Bad            game
# 2416                                       23: Born Bad            sick
# 1282                                       23: Born Bad           water
# 2217                                       23: Born Bad            baby
# 5162                                       23: Born Bad        listened
# 5210                                       23: Born Bad          sticky
# 3634                                       23: Born Bad          yellow
# 5076                                       23: Born Bad           blind
# 840                                        23: Born Bad             one
# 560                                        23: Born Bad            like
# 5092                    24: Elenita, Cards, Palm, Water           cards
# 1283                    24: Elenita, Cards, Palm, Water           water
# 4591                    24: Elenita, Cards, Palm, Water           heart
# 2806                    24: Elenita, Cards, Palm, Water             see
# 5175                    24: Elenita, Cards, Palm, Water            palm
# 5300                    24: Elenita, Cards, Palm, Water         geraldo
# 4790                    24: Elenita, Cards, Palm, Water          begins
# 1389                    24: Elenita, Cards, Palm, Water             yes
# 5286                    24: Elenita, Cards, Palm, Water          closes
# 5326                    24: Elenita, Cards, Palm, Water         plastic
# 1607                    24: Elenita, Cards, Palm, Water          anchor
# 4986                    24: Elenita, Cards, Palm, Water         kitchen
# 5267                    24: Elenita, Cards, Palm, Water            beer
# 5275                    24: Elenita, Cards, Palm, Water         bubbles
# 5278                    24: Elenita, Cards, Palm, Water          candle
# 5301                           25: Geraldo No Last Name         geraldo
# 5193                           25: Geraldo No Last Name          ruthie
# 3461                           25: Geraldo No Last Name         another
# 2279                           25: Geraldo No Last Name            edna
# 5385                           25: Geraldo No Last Name        hospital
# 5386                           25: Geraldo No Last Name           hours
# 5403                           25: Geraldo No Last Name         surgeon
# 4673                           25: Geraldo No Last Name            sent
# 5318                           25: Geraldo No Last Name             met
# 2843                           25: Geraldo No Last Name        somebody
# 1666                           25: Geraldo No Last Name         explain
# 2710                           25: Geraldo No Last Name          laughs
# 3397                           25: Geraldo No Last Name           marin
# 515                            25: Geraldo No Last Name            know
# 2380                           25: Geraldo No Last Name            lady
# 5194                                  26: Edna's Ruthie          ruthie
# 5422                                  26: Edna's Ruthie            earl
# 385                                   26: Edna's Ruthie              go
# 2280                                  26: Edna's Ruthie            edna
# 5036                                  26: Edna's Ruthie            week
# 5508                                  26: Edna's Ruthie       wonderful
# 2388                                  26: Edna's Ruthie           lives
# 786                                   26: Edna's Ruthie            next
# 3728                                  26: Edna's Ruthie           might
# 3313                                  26: Edna's Ruthie            came
# 5421                                  26: Edna's Ruthie            duck
# 5430                                  26: Edna's Ruthie          flower
# 5450                                  26: Edna's Ruthie           motor
# 5467                                  26: Edna's Ruthie          screen
# 5469                                  26: Edna's Ruthie         shining
# 5423                           27: The Earl of Tennesse            earl
# 3285                           27: The Earl of Tennesse       apartment
# 246                            27: The Earl of Tennesse            door
# 4858                           27: The Earl of Tennesse           opens
# 5524                           27: The Earl of Tennesse        dampness
# 5550                           27: The Earl of Tennesse            sigh
# 3383                           27: The Earl of Tennesse         looking
# 564                            27: The Earl of Tennesse            like
# 4470                           27: The Earl of Tennesse        whenever
# 5525                           27: The Earl of Tennesse            dogs
# 5551                           27: The Earl of Tennesse            sire
# 5562                           27: The Earl of Tennesse          walked
# 1655                           27: The Earl of Tennesse           comes
# 3622                           27: The Earl of Tennesse           wears
# 5136                           27: The Earl of Tennesse             hat
# 5591                                           28: Sire            lois
# 1229                                           28: Sire           trees
# 2528                                           28: Sire            bike
# 5360                                           28: Sire             tie
# 565                                            28: Sire            like
# 658                                            28: Sire          looked
# 333                                            28: Sire            four
# 2939                                           28: Sire            wait
# 4222                                           28: Sire            pink
# 5574                                           28: Sire        barefoot
# 5575                                           28: Sire          bumped
# 1577                                           28: Sire          smells
# 5552                                           28: Sire            sire
# 5585                                           28: Sire            grow
# 1785                                           28: Sire       sometimes
# 2371                              29: Four Skinny Trees            keep
# 334                               29: Four Skinny Trees            four
# 5618                              29: Four Skinny Trees           reach
# 5619                              29: Four Skinny Trees          reason
# 1230                              29: Four Skinny Trees           trees
# 4153                              29: Four Skinny Trees          forget
# 5608                              29: Four Skinny Trees           anger
# 5609                              29: Four Skinny Trees            bite
# 5610                              29: Four Skinny Trees         despite
# 5611                              29: Four Skinny Trees           droop
# 5612                              29: Four Skinny Trees            grab
# 5613                              29: Four Skinny Trees            grew
# 5614                              29: Four Skinny Trees           hairy
# 5623                              29: Four Skinny Trees         violent
# 5520                              29: Four Skinny Trees        concrete
# 1859                               30: No Speak English         english
# 4893                               30: No Speak English           speak
# 4223                               30: No Speak English            pink
# 3194                               30: No Speak English             man
# 5045                               30: No Speak English         country
# 5651                               30: No Speak English      hamandeggs
# 5661                               30: No Speak English        mamacita
# 927                                30: No Speak English            push
# 5668                               30: No Speak English            pull
# 1914                               30: No Speak English            home
# 2793                               30: No Speak English           saved
# 3813                               30: No Speak English             boy
# 2220                               30: No Speak English            baby
# 1084                               30: No Speak English          stairs
# 4431                               30: No Speak English          sounds
# 5713  31: Rafaela Who Drinks Coconut & Papaya Juice ...         rafaela
# 5050  31: Rafaela Who Drinks Coconut & Papaya Juice ...          drinks
# 5694  31: Rafaela Who Drinks Coconut & Papaya Juice ...         coconut
# 5707  31: Rafaela Who Drinks Coconut & Papaya Juice ...           juice
# 5710  31: Rafaela Who Drinks Coconut & Papaya Juice ...          papaya
# 5729  31: Rafaela Who Drinks Coconut & Papaya Juice ...        tuesdays
# 5718  31: Rafaela Who Drinks Coconut & Papaya Juice ...           sally
# 568   31: Rafaela Who Drinks Coconut & Papaya Juice ...            like
# 5708  31: Rafaela Who Drinks Coconut & Papaya Juice ...           leans
# 5728  31: Rafaela Who Drinks Coconut & Papaya Juice ...         sweeter
# 5732  31: Rafaela Who Drinks Coconut & Papaya Juice ...          wishes
# 1438  31: Rafaela Who Drinks Coconut & Papaya Juice ...            hair
# 4553  31: Rafaela Who Drinks Coconut & Papaya Juice ...           dance
# 3656  31: Rafaela Who Drinks Coconut & Papaya Juice ...       beautiful
# 1594  31: Rafaela Who Drinks Coconut & Papaya Juice ...           sweet
# 5719                                          32: Sally           sally
# 201                                           32: Sally           could
# 3541                                          32: Sally            love
# 1364                                          32: Sally           would
# 847                                           32: Sally             one
# 5752                                          32: Sally         minerva
# 1768                                          32: Sally           since
# 569                                           32: Sally            like
# 5772                                          32: Sally          writes
# 3125                                          32: Sally            feet
# 599                                           32: Sally          little
# 2119                                          32: Sally         waiting
# 3057                                          32: Sally           black
# 321                                           32: Sally           fence
# 2384                                          32: Sally            lean
# 885                            33: Minerva Writes Poems            papa
# 2172                           33: Minerva Writes Poems          window
# 248                            33: Minerva Writes Poems            door
# 390                            33: Minerva Writes Poems              go
# 2587                           33: Minerva Writes Poems          enough
# 2723                           33: Minerva Writes Poems            lets
# 4074                           33: Minerva Writes Poems            read
# 570                            33: Minerva Writes Poems            like
# 2359                           33: Minerva Writes Poems         getting
# 1658                           33: Minerva Writes Poems           comes
# 5782                           33: Minerva Writes Poems         gardens
# 5783                           33: Minerva Writes Poems            hill
# 5786                           33: Minerva Writes Poems           sends
# 5787                           33: Minerva Writes Poems         staring
# 5788                           33: Minerva Writes Poems         sundays
# 4275                              34: Bums in the Attic             ask
# 5796                              34: Bums in the Attic           cruel
# 5806                              34: Bums in the Attic           hills
# 610                               34: Bums in the Attic            live
# 2409                              34: Bums in the Attic            rats
# 5777                              34: Bums in the Attic           attic
# 5779                              34: Bums in the Attic            bums
# 849                               34: Bums in the Attic             one
# 2485                              34: Bums in the Attic              wo
# 3447                              34: Bums in the Attic            stay
# 3657                              34: Bums in the Attic       beautiful
# 4155                              34: Bums in the Attic          forget
# 462                               34: Bums in the Attic           house
# 1337                              34: Bums in the Attic         without
# 805                               34: Bums in the Attic         nothing
# 4907                              35: Beautiful & Cruel           train
# 5688                              35: Beautiful & Cruel          thread
# 5822                              35: Beautiful & Cruel            draw
# 5823                              35: Beautiful & Cruel           draws
# 5824                              35: Beautiful & Cruel         knotted
# 5825                              35: Beautiful & Cruel       languages
# 5826                              35: Beautiful & Cruel          needle
# 5829                              35: Beautiful & Cruel            silk
# 324                               35: Beautiful & Cruel             fix
# 3686                              35: Beautiful & Cruel        downtown
# 3787                              35: Beautiful & Cruel          subway
# 4930                              35: Beautiful & Cruel          arrive
# 5622                              35: Beautiful & Cruel          tulips
# 5674                              35: Beautiful & Cruel        rosebuds
# 5820                              35: Beautiful & Cruel          cookie
# 5834                                   36: Smart Cookie       butterfly
# 5840                                   36: Smart Cookie            hits
# 5845                                   36: Smart Cookie          madame
# 5846                                   36: Smart Cookie         oatmeal
# 435                                    36: Smart Cookie            hard
# 906                                    36: Smart Cookie          places
# 1048                                   36: Smart Cookie          school
# 5720                                   36: Smart Cookie           sally
# 3630                                   36: Smart Cookie           whose
# 2566                                   36: Smart Cookie         clothes
# 5146                                   36: Smart Cookie         husband
# 989                                    36: Smart Cookie            said
# 3361                                   36: Smart Cookie            girl
# 523                                    36: Smart Cookie            know
# 572                                    36: Smart Cookie            like
# 4560                                37: What Sally Said        daughter
# 5721                                37: What Sally Said           sally
# 1877                                37: What Sally Said          father
# 1311                                37: What Sally Said            went
# 2660                                37: What Sally Said           going
# 3317                                37: What Sally Said            came
# 5855                                37: What Sally Said            belt
# 5856                                37: What Sally Said          buckle
# 5857                                37: What Sally Said         catches
# 5858                                37: What Sally Said          crying
# 5861                                37: What Sally Said            imal
# 5862                                37: What Sally Said         knocked
# 5867                                37: What Sally Said      sweetbread
# 790                                 37: What Sally Said            next
# 2049                                37: What Sally Said            sack
# 5900                              38: The Monkey Garden          garden
# 5917                              38: The Monkey Garden          monkey
# 5722                              38: The Monkey Garden           sally
# 991                               38: The Monkey Garden            said
# 2151                              38: The Monkey Garden          wanted
# 86                                38: The Monkey Garden            back
# 4334                              38: The Monkey Garden            kiss
# 3562                              38: The Monkey Garden             ran
# 2916                              38: The Monkey Garden            tito
# 1625                              38: The Monkey Garden            boys
# 5930                              38: The Monkey Garden          pickup
# 2556                              38: The Monkey Garden            cars
# 4330                              38: The Monkey Garden            keys
# 574                               38: The Monkey Garden            like
# 4960                              38: The Monkey Garden            dead
# 5723                                     39: Red Clowns           sally
# 3714                                     39: Red Clowns         married
# 3542                                     39: Red Clowns            love
# 4468                                     39: Red Clowns          waited
# 4991                                     39: Red Clowns            lied
# 5994                                     39: Red Clowns            sour
# 5886                                     39: Red Clowns          clowns
# 958                                      39: Red Clowns        remember
# 537                                      39: Red Clowns           leave
# 709                                      39: Red Clowns            make
# 2091                                     39: Red Clowns         spanish
# 1369                                     39: Red Clowns           would
# 4928                                     39: Red Clowns           alone
# 5147                                     39: Red Clowns         husband
# 992                                      39: Red Clowns            said
# 3511                                 40: Linoleum Roses            gets
# 3007                                 40: Linoleum Roses             let
# 2315                                 40: Linoleum Roses          except
# 5998                                 40: Linoleum Roses           alarm
# 5999                                 40: Linoleum Roses          drapes
# 6000                                 40: Linoleum Roses          neatly
# 6001                                 40: Linoleum Roses          smooth
# 6002                                 40: Linoleum Roses       telephone
# 6003                                 40: Linoleum Roses         toaster
# 184                                  40: Linoleum Roses         ceiling
# 3075                                 40: Linoleum Roses         corners
# 3723                                 40: Linoleum Roses            meet
# 4948                                 40: Linoleum Roses           clock
# 5368                                 40: Linoleum Roses         wedding
# 5496                                 40: Linoleum Roses           visit
# 1391                              41: The Three Sisters             yes
# 993                               41: The Three Sisters            said
# 2961                              41: The Three Sisters            wish
# 1866                              41: The Three Sisters       esperanza
# 4363                              41: The Three Sisters            must
# 4175                              41: The Three Sisters           hands
# 2203                              41: The Three Sisters          alicia
# 853                               41: The Three Sisters             one
# 3319                              41: The Three Sisters            came
# 41                                41: The Three Sisters           asked
# 525                               41: The Three Sisters            know
# 1183                              41: The Three Sisters           three
# 538                               41: The Three Sisters           leave
# 959                               41: The Three Sisters        remember
# 2682                              41: The Three Sisters            good
# 6044             42: Alicia & I Talking on Edna's Steps           mayor
# 465              42: Alicia & I Talking on Edna's Steps           house
# 1455             42: Alicia & I Talking on Edna's Steps           makes
# 2204             42: Alicia & I Talking on Edna's Steps          alicia
# 733              42: Alicia & I Talking on Edna's Steps           mango
# 2028             42: Alicia & I Talking on Edna's Steps          nobody
# 1110             42: Alicia & I Talking on Edna's Steps          street
# 2662             42: Alicia & I Talking on Edna's Steps           going
# 6042             42: Alicia & I Talking on Edna's Steps          beside
# 6043             42: Alicia & I Talking on Edna's Steps            loud
# 6045             42: Alicia & I Talking on Edna's Steps        petunias
# 6046             42: Alicia & I Talking on Edna's Steps          purple
# 6047             42: Alicia & I Talking on Edna's Steps           space
# 326              42: Alicia & I Talking on Edna's Steps            flat
# 4081             42: Alicia & I Talking on Edna's Steps            snow
# 1132                              43: A House of My Own            tell
# 6048                              43: A House of My Own            mail
# 1097                              43: A House of My Own         stories
# 2096                              43: A House of My Own           story
# 3822                              43: A House of My Own           brown
# 6049                              43: A House of My Own         mailman
# 6050                              43: A House of My Own         trudged
# 4439                              43: A House of My Own            step
# 5472                              43: A House of My Own            shoe
# ...
# 1534          0.014348
# 1569          0.013678
# 540           0.013404
# 879           0.013088
# 1401          0.010316
# 1402          0.010316
# 1403          0.010316
# 1414          0.010316
# 1441          0.010316
# 1450          0.010316
# 1680          0.020517
# 1618          0.018839
# 1670          0.018122
# 1608          0.017155
# 761           0.014847
# 1611          0.013678
# 1687          0.010316
# 1717          0.010316
# 1752          0.010316
# 1759          0.010316
# 1812          0.010316
# 1817          0.010316
# 1606          0.009299
# 1627          0.009299
# 1661          0.009299
# 1999          0.054365
# 1975          0.032071
# 1845          0.030947
# 1924          0.027896
# 542           0.026808
# 1957          0.020631
# 2189          0.020631
# 1860          0.019631
# 1840          0.017155
# 2050          0.017155
# 2181          0.017155
# 2160          0.016036
# 684           0.015788
# 2087          0.015121
# 2175          0.014348
# 2248          0.111586
# 424           0.034310
# 2404          0.030947
# 2245          0.025732
# 2337          0.020631
# 2349          0.020631
# 2361          0.020631
# 2430          0.018598
# 2237          0.017155
# 738           0.016036
# 2396          0.015121
# 776           0.014417
# 2283          0.013678
# 1871          0.013088
# 2262          0.013088
# 2581          0.083689
# 2625          0.083689
# 2527          0.046494
# 2773          0.042887
# 2763          0.042284
# 2739          0.037677
# 2246          0.034310
# 2898          0.030947
# 352           0.028589
# 1008          0.025685
# 2010          0.021522
# 2724          0.020631
# 2917          0.019631
# 2040          0.018598
# 2525          0.018598
# 3014          0.027896
# 2740          0.018839
# 545           0.018765
# 469           0.018598
# 2994          0.018598
# 2764          0.018122
# 2989          0.017155
# 1719          0.016865
# 764           0.014847
# 1425          0.013678
# 451           0.012907
# 654           0.012081
# 626           0.011093
# 2967          0.010316
# 2992          0.010316
# 3069          0.040089
# 3185          0.033730
# 810           0.028108
# 3067          0.027896
# 765           0.024744
# 2434          0.021522
# 3037          0.020631
# 3241          0.020631
# 1802          0.020517
# 2431          0.018598
# 3127          0.018598
# 3135          0.018598
# 1137          0.015303
# 2798          0.014417
# 3113          0.014348
# 3399          0.103156
# 1426          0.041035
# 3389          0.040089
# 3330          0.037803
# 3451          0.027896
# 2247          0.025732
# 3404          0.025732
# 2001          0.024162
# 743           0.022682
# 3416          0.020631
# 3436          0.020631
# 3453          0.020631
# 2263          0.019631
# 3304          0.018598
# 3417          0.018598
# 3390          0.080178
# 165           0.054365
# 3457          0.051578
# 2264          0.039263
# 3632          0.035870
# 3485          0.030947
# 3487          0.030947
# 3495          0.030947
# 679           0.025732
# 2534          0.022682
# 3573          0.020631
# 1772          0.020517
# 36            0.019631
# 1193          0.018165
# 1315          0.018122
# 3395          0.083167
# 1264          0.030606
# 1763          0.025118
# 1619          0.018839
# 3559          0.017155
# 355           0.016337
# 2444          0.016036
# 3646          0.016036
# 3698          0.016036
# 1138          0.015303
# 2799          0.014417
# 3276          0.014348
# 3771          0.014348
# 1375          0.013678
# 1613          0.013678
# 2392          0.017155
# 1888          0.013678
# 3807          0.012559
# 2600          0.012081
# 3806          0.010316
# 3816          0.010316
# 3823          0.010316
# 3828          0.010316
# 3829          0.010316
# 3834          0.010316
# 3844          0.010316
# 1152          0.009611
# 3684          0.009299
# 3824          0.009299
# 3826          0.009299
# 1689          0.024162
# 270           0.021743
# 1333          0.018122
# 1960          0.016307
# 1814          0.016036
# 3942          0.013678
# 2225          0.013088
# 1634          0.012907
# 215           0.011945
# 507           0.010829
# 3857          0.010316
# 3860          0.010316
# 3861          0.010316
# 3862          0.010316
# 3867          0.010316
# 2200          0.021522
# 3998          0.020631
# 4008          0.020631
# 4009          0.020631
# 4010          0.020631
# 4019          0.020631
# 2054          0.017155
# 3982          0.017155
# 1873          0.013088
# 3960          0.013088
# 715           0.010526
# 3959          0.010316
# 3972          0.010316
# 3985          0.010316
# 3986          0.010316
# 4048          0.051578
# 3928          0.026175
# 4054          0.025732
# 1416          0.024053
# 3158          0.024053
# 4058          0.018839
# 4080          0.018598
# 4086          0.018598
# 978           0.016337
# 3091          0.016036
# 4044          0.016036
# 2801          0.014417
# 4035          0.013678
# 2918          0.013088
# 1014          0.012843
# 4118          0.072209
# 4045          0.048107
# 3406          0.042887
# 3048          0.039263
# 4129          0.037677
# 553           0.037531
# 4250          0.034196
# 3121          0.032719
# 2766          0.030203
# 767           0.029693
# 666           0.028108
# 716           0.026314
# 1862          0.026175
# 2742          0.025118
# 2602          0.024162
# 2822          0.091817
# 4283          0.051578
# 4343          0.051578
# 2767          0.048324
# 2743          0.043957
# 4367          0.040089
# 554           0.037531
# 3096          0.030242
# 3473          0.030203
# 4313          0.028696
# 1384          0.028108
# 3189          0.028108
# 3220          0.027896
# 4285          0.027896
# 1016          0.025685
# 2011          0.043044
# 717           0.036839
# 4618          0.030947
# 4703          0.030947
# 4563          0.030242
# 1691          0.030203
# 1043          0.028108
# 3710          0.027896
# 4650          0.027896
# 4717          0.027896
# 272           0.027179
# 1178          0.024162
# 4304          0.024053
# 4350          0.024053
# 379           0.022733
# 4718          0.046494
# 4548          0.034196
# 4777          0.030947
# 1463          0.019796
# 556           0.018765
# 4760          0.017155
# 1386          0.016865
# 2012          0.014348
# 4636          0.013678
# 3124          0.013088
# 1621          0.012559
# 3810          0.012559
# 2619          0.011243
# 4736          0.010316
# 4737          0.010316
# 4637          0.054713
# 4749          0.051464
# 3607          0.046494
# 1387          0.044973
# 2744          0.037677
# 4908          0.037195
# 2768          0.036243
# 4789          0.034310
# 1738          0.033527
# 362           0.032673
# 769           0.029693
# 557           0.029488
# 412           0.028589
# 4404          0.027896
# 1805          0.027357
# 4988          0.041262
# 982           0.032673
# 3647          0.032071
# 4691          0.032071
# 5005          0.030947
# 782           0.028833
# 3310          0.026314
# 881           0.026175
# 1197          0.022707
# 4972          0.020631
# 5003          0.020631
# 5004          0.020631
# 5013          0.020631
# 3410          0.020517
# 381           0.018944
# 4595          0.028696
# 5058          0.020631
# 5059          0.020631
# 882           0.019631
# 1842          0.017155
# 3648          0.016036
# 1600          0.013678
# 2922          0.013088
# 3080          0.012081
# 5041          0.010316
# 5048          0.010316
# 5054          0.010316
# 5055          0.010316
# 5060          0.010316
# 5061          0.010316
# 4638          0.054713
# 222           0.051763
# 3649          0.048107
# 5223          0.041262
# 4032          0.037195
# 5131          0.037195
# 2416          0.034310
# 1282          0.034196
# 2217          0.033730
# 5162          0.030947
# 5210          0.030947
# 3634          0.028696
# 5076          0.027896
# 840           0.026988
# 560           0.026808
# 5092          0.034310
# 1283          0.034196
# 4591          0.032071
# 2806          0.028833
# 5175          0.027896
# 5300          0.027896
# 4790          0.025732
# 1389          0.022487
# 5286          0.020631
# 5326          0.020631
# 1607          0.018598
# 4986          0.018598
# 5267          0.018598
# 5275          0.018598
# 5278          0.018598
# 5301          0.037195
# 5193          0.025732
# 3461          0.022682
# 2279          0.021522
# 5385          0.020631
# 5386          0.020631
# 5403          0.020631
# 4673          0.017155
# 5318          0.017155
# 2843          0.016307
# 1666          0.016036
# 2710          0.015121
# 3397          0.015121
# 515           0.014438
# 2380          0.013678
# 5194          0.145816
# 5422          0.037195
# 385           0.034099
# 2280          0.028696
# 5036          0.028696
# 5508          0.027896
# 2388          0.024053
# 786           0.024028
# 3728          0.022682
# 3313          0.021051
# 5421          0.020631
# 5430          0.020631
# 5450          0.020631
# 5467          0.020631
# 5469          0.020631
# 5423          0.046494
# 3285          0.028696
# 246           0.028108
# 4858          0.025732
# 5524          0.020631
# 5550          0.020631
# 3383          0.018839
# 564           0.018765
# 4470          0.018598
# 5525          0.018598
# 5551          0.018598
# 5562          0.018598
# 1655          0.017467
# 3622          0.017155
# 5136          0.017155
# 5591          0.030947
# 1229          0.028696
# 2528          0.027896
# 5360          0.027896
# 565           0.026808
# 658           0.024162
# 333           0.024053
# 2939          0.022682
# 4222          0.022682
# 5574          0.020631
# 5575          0.020631
# 1577          0.018598
# 5552          0.018598
# 5585          0.018598
# 1785          0.016307
# 2371          0.030203
# 334           0.024053
# 5618          0.020631
# 5619          0.018598
# 1230          0.014348
# 4153          0.013088
# 5608          0.010316
# 5609          0.010316
# 5610          0.010316
# 5611          0.010316
# 5612          0.010316
# 5613          0.010316
# 5614          0.010316
# 5623          0.010316
# 5520          0.009299
# 1859          0.068045
# 4893          0.064142
# 4223          0.037803
# 3194          0.033730
# 5045          0.032071
# 5651          0.030947
# 5661          0.030947
# 927           0.027896
# 5668          0.027896
# 1914          0.027248
# 2793          0.025732
# 3813          0.025118
# 2220          0.022487
# 1084          0.020517
# 4431          0.018598
# 5713          0.072209
# 5050          0.046494
# 5694          0.030947
# 5707          0.030947
# 5710          0.030947
# 5729          0.030947
# 5718          0.021522
# 568           0.021446
# 5708          0.020631
# 5728          0.020631
# 5732          0.020631
# 1438          0.020517
# 4553          0.020517
# 3656          0.019631
# 1594          0.016036
# 5719          0.057392
# 201           0.032690
# 3541          0.030242
# 1364          0.028020
# 847           0.026988
# 5752          0.025732
# 1768          0.025118
# 569           0.024127
# 5772          0.020631
# 3125          0.019631
# 599           0.019417
# 2119          0.018839
# 3057          0.018839
# 321           0.018598
# 2384          0.018598
# 885           0.019631
# 2172          0.017467
# 248           0.016865
# 390           0.015155
# 2587          0.015121
# 2723          0.014348
# 4074          0.013678
# 570           0.013404
# 2359          0.013088
# 1658          0.011645
# 5782          0.010316
# 5783          0.010316
# 5786          0.010316
# 5787          0.010316
# 5788          0.010316
# 4275          0.025732
# 5796          0.020631
# 5806          0.020631
# 610           0.018839
# 2409          0.018598
# 5777          0.018598
# 5779          0.018598
# 849           0.014993
# 2485          0.013678
# 3447          0.013088
# 3657          0.013088
# 4155          0.013088
# 462           0.012907
# 1337          0.012081
# 805           0.011645
# 4907          0.018598
# 5688          0.018598
# 5822          0.010316
# 5823          0.010316
# 5824          0.010316
# 5825          0.010316
# 5826          0.010316
# 5829          0.010316
# 324           0.009299
# 3686          0.009299
# 3787          0.009299
# 4930          0.009299
# 5622          0.009299
# 5674          0.009299
# 5820          0.009299
# 5834          0.020631
# 5840          0.020631
# 5845          0.020631
# 5846          0.020631
# 435           0.019631
# 906           0.017155
# 1048          0.016865
# 5720          0.014348
# 3630          0.013678
# 2566          0.013088
# 5146          0.012559
# 989           0.012252
# 3361          0.012081
# 523           0.010829
# 572           0.010723
# 4560          0.022682
# 5721          0.021522
# 1877          0.019631
# 1311          0.011243
# 2660          0.010526
# 3317          0.010526
# 5855          0.010316
# 5856          0.010316
# 5857          0.010316
# 5858          0.010316
# 5861          0.010316
# 5862          0.010316
# 5867          0.010316
# 790           0.009611
# 2049          0.009299
# 5900          0.165050
# 5917          0.103156
# 5722          0.086088
# 991           0.061262
# 2151          0.052350
# 86            0.039818
# 4334          0.037803
# 3562          0.034310
# 2916          0.032071
# 1625          0.031398
# 5930          0.030947
# 2556          0.030242
# 4330          0.030242
# 574           0.029488
# 4960          0.028696
# 5723          0.050218
# 3714          0.040089
# 3542          0.037803
# 4468          0.025732
# 4991          0.025732
# 5994          0.020631
# 5886          0.018598
# 958           0.016307
# 537           0.016036
# 709           0.015788
# 2091          0.015121
# 1369          0.014010
# 4928          0.013678
# 5147          0.012559
# 992           0.012252
# 3511          0.012559
# 3007          0.011243
# 2315          0.010526
# 5998          0.010316
# 5999          0.010316
# 6000          0.010316
# 6001          0.010316
# 6002          0.010316
# 6003          0.010316
# 184           0.009299
# 3075          0.009299
# 3723          0.009299
# 4948          0.009299
# 5368          0.009299
# 5496          0.009299
# 1391          0.044973
# 993           0.044925
# 2961          0.040089
# 1866          0.039263
# 4363          0.034310
# 4175          0.031398
# 2203          0.028696
# 853           0.026988
# 3319          0.026314
# 41            0.026175
# 525           0.025267
# 1183          0.024162
# 538           0.024053
# 959           0.021743
# 2682          0.021743
# 6044          0.030947
# 465           0.021512
# 1455          0.015121
# 2204          0.014348
# 733           0.012081
# 2028          0.011243
# 1110          0.010526
# 2662          0.010526
# 6042          0.010316
# 6043          0.010316
# 6045          0.010316
# 6046          0.010316
# 6047          0.010316
# 326           0.009299
# 4081          0.009299
# 1132          0.024744
# 6048          0.020631
# 1097          0.015121
# 2096          0.015121
# 3822          0.014348
# 6049          0.010316
# 6050          0.010316
# 4439          0.008577
# 5472          0.008577
# 1953          0.008018
# 2446          0.008018
# 4162          0.008018
# 5219          0.008018
# 1347          0.007174
# 4798          0.007174
# 735           0.024162
# 4378          0.019631
# 483           0.018598
# 4163          0.016036
# 618           0.015121
# 4799          0.014348
# 4518          0.013678
# 4007          0.012559
# 65            0.011945
# 233           0.011945
# 1111          0.010526
# 6051          0.010316
# 6052          0.010316
# 6053          0.010316
# 6054          0.010316

# %% [markdown]
# It turns out that "pigeons" are pretty unique to the first chapter in *The House on Mango Street* and have a normalized tf-idf score of .062, making it one of the most distinctive words in that story along with "coop" and "birds."
#
# What are some other distinctive words in *The House on Mango Street*?

# %% [markdown]
# ## Further Resources

# %% [markdown]
# - Peter Organisciak and Boris Capitanu, ["Text Mining in Python through the HTRC Feature Reader,"](https://programminghistorian.org/en/lessons/text-mining-with-extracted-features) *The Programming Historian*
